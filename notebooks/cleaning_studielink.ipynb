# %%
import pandas as pd
import numpy as np
import seaborn as sns
from functools import reduce
import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
from IPython.display import display

# %%
# Load the Excel file
file_path = '../data/raw/ODS Studielink Aanmeldingen.xlsx'
data = pd.read_excel(file_path, sheet_name=None)

# Print the names of all sheets
print("Sheet names:", data.keys())

# Display the first few rows of each sheet
for sheet_name, sheet_data in data.items():
    print(f"---{sheet_name}---")
    print(sheet_data.head())
# Out:
# Sheet names: dict_keys(['vooraf', 'ODS.ANM_TELBESTAND_SL'])
# ---vooraf---
#                                           Unnamed: 0
# 0                               Herkomst: NL/EER/...
# 1  Status:   verzoek/afwijzing/uitschrijving/insc...
# 2  Meercode: V = alle niet-geannuleerde inschrijf...
# 3            A = alle geannuleerde inschrijfverzo...
# 4  1cHO:     hoogste niveau waarop de student voo...
# ---ODS.ANM_TELBESTAND_SL---
#   HBO_WO BRINCODE  BRIN_VOLGNR  ISATCODE TYPE_HO  OPL_VORM  STUDIEJAAR FIXUS  \
# 0      W     21PK            0     60227       M         2        2023     N
# 1      W     21PK            0     60227       M         2        2023     N
# 2      W     21PK            0     60228       M         1        2023     N
# 3      W     21PK            0     60228       M         1        2023     N
# 4      W     21PK            0     60228       M         1        2023     N
#
#    MAAND HERKOMST GESLACHT  MEERCODE_V  MEERCODE_A STATUS HOGEREJAARS  \
# 0      9        N        M           1           0      I           J
# 1      9        E        M           0           3      A           N
# 2      1        R        M           0           5      A           N
# 3      9        E        V           0           1      A           N
# 4      9        R        V           0           1      A           N
#
#   HERINSCHRIJVING  1CHO_L  1CHO_K  AANTAL
# 0               J     6.0     6.0       5
# 1               N     3.0     4.0       1
# 2               N     1.0     1.0       1
# 3               N     1.0     1.0       1
# 4               N     NaN     NaN       2

# %%
# Path to your Excel file
file_path = '../data/raw/ODS Studielink Aanmeldingen.xlsx'

# Load the Excel file, excluding the 'vooraf' sheet
excel_data = pd.ExcelFile(file_path)
sheet_names = excel_data.sheet_names

# Remove 'vooraf' from the list of sheet names
if 'vooraf' in sheet_names:
    sheet_names.remove('vooraf')

# Loop through sheet names and assign each DataFrame to a variable
for i, sheet_name in enumerate(sheet_names):
    df_name = f'df{i + 1}'  # Create a variable name like df1, df2, etc.
    globals()[df_name] = pd.read_excel(file_path, sheet_name=sheet_name)  # Load each sheet into a DataFrame

# Display the first 5 rows of each DataFrame to verify
for i in range(1, len(sheet_names) + 1):
    df_name = f'df{i}'
    print(f"DataFrame: {df_name}")
    display(globals()[df_name].head(5))
# Out:
# DataFrame: df1
#   HBO_WO BRINCODE  BRIN_VOLGNR  ISATCODE TYPE_HO  OPL_VORM  STUDIEJAAR FIXUS  \
# 0      W     21PK            0     60227       M         2        2023     N
# 1      W     21PK            0     60227       M         2        2023     N
# 2      W     21PK            0     60228       M         1        2023     N
# 3      W     21PK            0     60228       M         1        2023     N
# 4      W     21PK            0     60228       M         1        2023     N
#
#    MAAND HERKOMST GESLACHT  MEERCODE_V  MEERCODE_A STATUS HOGEREJAARS  \
# 0      9        N        M           1           0      I           J
# 1      9        E        M           0           3      A           N
# 2      1        R        M           0           5      A           N
# 3      9        E        V           0           1      A           N
# 4      9        R        V           0           1      A           N
#
#   HERINSCHRIJVING  1CHO_L  1CHO_K  AANTAL
# 0               J     6.0     6.0       5
# 1               N     3.0     4.0       1
# 2               N     1.0     1.0       1
# 3               N     1.0     1.0       1
# 4               N     NaN     NaN       2

# %%
df1.columns
# Out:
# Index(['HBO_WO', 'BRINCODE', 'BRIN_VOLGNR', 'ISATCODE', 'TYPE_HO', 'OPL_VORM',
#        'STUDIEJAAR', 'FIXUS', 'MAAND', 'HERKOMST', 'GESLACHT', 'MEERCODE_V',
#        'MEERCODE_A', 'STATUS', 'HOGEREJAARS', 'HERINSCHRIJVING', '1CHO_L',
#        '1CHO_K', 'AANTAL'],
#       dtype='object')

# %% [markdown]
# 'HBO_WO', 'BRINCODE', 'BRIN_volgNR', 'ISATCODE', 'TYPE_HO', 'OPL_VORM',
#  'STUDY YEAR', 'FIXUS', 'MONTH', 'ORIGIN', 'GENDER', 'MEERCODE_V',
#  'MEERCODE_A', 'STATUS', 'SENIOR YEARS', 'RE-REGISTRATION', '1CHO_L',
#  '1CHO_K', 'NUMBER'
